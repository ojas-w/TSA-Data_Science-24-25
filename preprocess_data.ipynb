# %%
import pandas as pd

# %%
df = pd.read_csv("/workspaces/TSA-Data_Science-24-25/raw data/ACSST5Y2010.S1901-2025-01-10T102329.csv")

df.iloc[11, [1, 9, 17, 25, 33, 41, 49, 57, 65, 73, 81, 89]]
# Out:
# Autauga County, Alabama!!Households!!Estimate     53,255
# Baldwin County, Alabama!!Households!!Estimate     50,147
# Barbour County, Alabama!!Households!!Estimate     33,219
# Bibb County, Alabama!!Households!!Estimate        41,770
# Blount County, Alabama!!Households!!Estimate      45,549
# Bullock County, Alabama!!Households!!Estimate     31,602
# Butler County, Alabama!!Households!!Estimate      30,659
# Calhoun County, Alabama!!Households!!Estimate     38,407
# Chambers County, Alabama!!Households!!Estimate    31,467
# Cherokee County, Alabama!!Households!!Estimate    40,690
# Chilton County, Alabama!!Households!!Estimate     39,486
# Choctaw County, Alabama!!Households!!Estimate     31,076
# Name: 11, dtype: object

# %%
# Dictionary of state names to abbreviations
state_abbrev = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
    'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
    'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
    'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
    'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO',
    'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ',
    'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH',
    'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC',
    'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT',
    'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY',
    'District of Columbia': 'DC'
}

# Get the relevant column indices (every 8th column starting from index 1)
relevant_cols = list(range(1, df.shape[1], 8))
print("Relevant Columns:", relevant_cols)

# Initialize lists to store our data
states = []
counties = []
metrics = []

# Extract data for each relevant column
for col_idx in relevant_cols:
    # Get column name and split it to extract location info
    col_name = df.columns[col_idx]
    print(f"Processing Column {col_idx}: {col_name}")

    location_info = col_name.split('!!')[0]  # Split by !! to remove other info
    county, state = location_info.split(',')  # Split county and state
    
    # Clean up by stripping whitespace
    county = county.strip()
    state = state.strip()
    
    # Convert state to abbreviation if it exists in our dictionary
    state_abbr = state_abbrev.get(state, state)  # Use original name if not found
    
    # Get the metric from row 11 (12th row)
    metric = df.iloc[11, col_idx]
    print(f"Extracted Data - County: {county}, State: {state}, Metric: {metric}")
    
    # Append to our lists
    counties.append(county)
    states.append(state_abbr)
    metrics.append(metric)

# Create new DataFrame
income_df = pd.DataFrame({
    'State': states,
    'County': counties,
    'Metric': metrics
})

# Remove Puerto Rico rows
income_df = income_df[income_df['State'] != 'Puerto Rico']

income_df.head()
# Out:
# Relevant Columns: [1, 9, 17, 25, 33, 41, 49, 57, 65, 73, 81, 89, 97, 105, 113, 121, 129, 137, 145, 153, 161, 169, 177, 185, 193, 201, 209, 217, 225, 233, 241, 249, 257, 265, 273, 281, 289, 297, 305, 313, 321, 329, 337, 345, 353, 361, 369, 377, 385, 393, 401, 409, 417, 425, 433, 441, 449, 457, 465, 473, 481, 489, 497, 505, 513, 521, 529, 537, 545, 553, 561, 569, 577, 585, 593, 601, 609, 617, 625, 633, 641, 649, 657, 665, 673, 681, 689, 697, 705, 713, 721, 729, 737, 745, 753, 761, 769, 777, 785, 793, 801, 809, 817, 825, 833, 841, 849, 857, 865, 873, 881, 889, 897, 905, 913, 921, 929, 937, 945, 953, 961, 969, 977, 985, 993, 1001, 1009, 1017, 1025, 1033, 1041, 1049, 1057, 1065, 1073, 1081, 1089, 1097, 1105, 1113, 1121
, 4185, 4193, 4201, 4209, 4217, 4225, 4233, 4241, 4249, 4257, 4265, 4273, 4281, 4289, 4297, 4305, 4313, 4321, 4329, 4337, 4345, 4353, 4361, 4369, 4377, 4385, 4393, 4401, 4409, 4417, 4425, 4433, 4441, 4449, 4457, 4465, 4473, 4481, 4489, 4497, 4505, 4513, 4521, 4529, 4537, 4545, 4553, 4561, 4569, 4577, 4585, 4593, 4601, 4609, 4617, 4625, 4633, 4641, 4649, 4657, 4665, 4673, 4681, 4689, 4697, 4705, 4713, 4721, 4729, 4737, 4745, 4753, 4761, 4769, 4777, 4785, 4793, 4801, 4809, 4817, 4825, 4833, 4841, 4849, 4857, 4865, 4873, 4881, 4889, 4897, 4905, 4913, 4921, 4929, 4937, 4945, 4953, 4961, 4969, 4977, 4985, 4993, 5001, 5009, 5017, 5025, 5033, 5041, 5049, 5057, 5065, 5073, 5081, 5089, 5097, 5105, 5113, 5121, 5129, 5137, 5145, 5153, 5161, 5169, 5177, 5185, 5193, 5201, 5209, 5217, 5225, 5233, 5241, 5249, 5257, 5265, 5273, 5281, 5289, 5297, 5305, 5313, 5321, 5329, 5337, 5345, 5353, 5361, 5369, 5377, 5385, 5393, 5401, 5409, 5417, 5425, 5433, 5441, 5449, 5457, 5465, 5473, 5481, 5489, ...
# Processing Column 1: Autauga County, Alabama!!Households!!Estimate
# Extracted Data - County: Autauga County, State: Alabama, Metric: 53,255
# Processing Column 9: Baldwin County, Alabama!!Households!!Estimate
# Extracted Data - County: Baldwin County, State: Alabama, Metric: 50,147
# Processing Column 17: Barbour County, Alabama!!Households!!Estimate
# Extracted Data - County: Barbour County, State: Alabama, Metric: 33,219
# Processing Column 25: Bibb County, Alabama!!Households!!Estimate
# Extracted Data - County: Bibb County, State: Alabama, Metric: 41,770
# Processing Column 33: Blount County, Alabama!!Households!!Estimate
# Extracted Data - County: Blount County, State: Alabama, Metric: 45,549
# Processing Column 41: Bullock County, Alabama!!Households!!Estimate
# Extracted Data - County: Bullock County, State: Alabama, Metric: 31,602
# Processing Column 49: Butler County, Alabama!!Households!!Estimate
# Extracted Data - County: Butler County, State: Alabama, Metric: 30,659
# Processing Column 57: Calhoun County, Alabama!!Households!!Estimate
# Extracted Data - County: Calhoun County, State: Alabama, Metric: 38,407
# Processing Column 65: Chambers County, Alabama!!Households!!Estimate
# Extracted Data - County: Chambers County, State: Alabama, Metric: 31,467
# Processing Column 73: Cherokee County, Alabama!!Households!!Estimate
# Extracted Data - County: Cherokee County, State: Alabama, Metric: 40,690
# Processing Column 81: Chilton County, Alabama!!Households!!Estimate
# Extracted Data - County: Chilton County, State: Alabama, Metric: 39,486
# Processing Column 89: Choctaw County, Alabama!!Households!!Estimate
# Extracted Data - County: Choctaw County, State: Alabama, Metric: 31,076
# Processing Column 97: Clarke County, Alabama!!Households!!Estimate
# Extracted Data - County: Clarke County, State: Alabama, Metric: 27,439
# Processing Column 105: Clay County, Alabama!!Households!!Estimate
# Extracted Data - County: Clay County, State: Alabama, Metric: 35,595
# Processing Column 113: Cleburne County, Alabama!!Households!!Estimate
# Extracted Data - County: Cleburne County, State: Alabama, Metric: 36,077
# Processing Column 121: Coffee County, Alabama!!Households!!Estimate
# Extracted Data - County: Coffee County, State: Alabama, Metric: 42,253
# Processing Column 129: Colbert County, Alabama!!Households!!Estimate
# Extracted Data - County: Colbert County, State: Alabama, Metric: 39,610
# Processing Column 137: Conecuh County, Alabama!!Households!!Estimate
# Extracted Data - County: Conecuh County, State: Alabama, Metric: 26,944
# Processing Column 145: Coosa County, Alabama!!Households!!Estimate
# Extracted Data - County: Coosa County, State: Alabama, Metric: 35,560
# Processing Column 153: Covington County, Alabama!!Households!!Estimate
# Extracted Data - County: Covington County, State: Alabama, Metric: 33,852
# Processing Column 161: Crenshaw County, Alabama!!Households!!Estimate
# Extracted Data - County: Crenshaw County, State: Alabama, Metric: 35,140
# Processing Column 169: Cullman County, Alabama!!Households!!Estimate
# Extracted Data - County: Cullman County, State: Alabama, Metric: 38,567
# Processing Column 177: Dale County, Alabama!!Households!!Estimate
# Extracted Data - County: Dale County, State: Alabama, Metric: 43,353
# Processing Column 185: Dallas County, Alabama!!Households!!Estimate
# Extracted Data - County: Dallas County, State: Alabama, Metric: 26,029
# Processing Column 193: DeKalb County, Alabama!!Households!!Estimate
# Extracted Data - County: DeKalb County, State: Alabama, Metric: 35,065
# Processing Column 201: Elmore County, Alabama!!Households!!Estimate
# Extracted Data - County: Elmore County, State: Alabama, Metric: 53,128
# Processing Column 209: Escambia County, Alabama!!Households!!Estimate
# Extracted Data - County: Escambia County, State: Alabama, Metric: 31,927
# Processing Column 217: Etowah County, Alabama!!Households!!Estimate
# Extracted Data - County: Etowah County, State: Alabama, Metric: 36,422
# Processing Column 225: Fayette County, Alabama!!Households!!Estimate
# Extracted Data - County: Fayette County, State: Alabama, Metric: 34,560
# Processing Column 233: Franklin County, Alabama!!Households!!Estimate
# Extracted Data - County: Franklin County, State: Alabama, Metric: 33,942
# Processing Column 241: Geneva County, Alabama!!Households!!Estimate
# Extracted Data - County: Geneva County, State: Alabama, Metric: 34,140
# Processing Column 249: Greene County, Alabama!!Households!!Estimate
# Extracted Data - County: Greene County, State: Alabama, Metric: 22,222
# Processing Column 257: Hale County, Alabama!!Households!!Estimate
# Extracted Data - County: Hale County, State: Alabama, Metric: 29,299
# Processing Column 265: Henry County, Alabama!!Households!!Estimate
# Extracted Data - County: Henry County, State: Alabama, Metric: 38,379
# Processing Column 273: Houston County, Alabama!!Households!!Estimate
# Extracted Data - County: Houston County, State: Alabama, Metric: 41,022
# Processing Column 281: Jackson County, Alabama!!Households!!Estimate
# Extracted Data - County: Jackson County, State: Alabama, Metric: 36,312
# Processing Column 289: Jefferson County, Alabama!!Households!!Estimate
# Extracted Data - County: Jefferson County, State: Alabama, Metric: 45,244
# Processing Column 297: Lamar County, Alabama!!Households!!Estimate
# Extracted Data - County: Lamar County, State: Alabama, Metric: 33,887
# Processing Column 305: Lauderdale County, Alabama!!Households!!Estimate
# Extracted Data - County: Lauderdale County, State: Alabama, Metric: 39,345
# Processing Column 313: Lawrence County, Alabama!!Households!!Estimate
# Extracted Data - County: Lawrence County, State: Alabama, Metric: 40,516
# Processing Column 321: Lee County, Alabama!!Households!!Estimate
# Extracted Data - County: Lee County, State: Alabama, Metric: 40,894
# Processing Column 329: Limestone County, Alabama!!Households!!Estimate
# Extracted Data - County: Limestone County, State: Alabama, Metric: 46,682
# Processing Column 337: Lowndes County, Alabama!!Households!!Estimate
# Extracted Data - County: Lowndes County, State: Alabama, Metric: 29,714
# Processing Column 345: Macon County, Alabama!!Households!!Estimate
# Extracted Data - County: Macon County, State: Alabama, Metric: 27,544
# Processing Column 353: Madison County, Alabama!!Households!!Estimate
# Extracted Data - County: Madison County, State: Alabama, Metric: 55,851
# Processing Column 361: Marengo County, Alabama!!Households!!Estimate
# Extracted Data - County: Marengo County, State: Alabama, Metric: 32,940
# Processing Column 369: Marion County, Alabama!!Households!!Estimate
# Extracted Data - County: Marion County, State: Alabama, Metric: 32,769
# Processing Column 377: Marshall County, Alabama!!Households!!Estimate
# Extracted Data - County: Marshall County, State: Alabama, Metric: 37,661
# Processing Column 385: Mobile County, Alabama!!Households!!Estimate
# Extracted Data - County: Mobile County, State: Alabama, Metric: 40,996
# Processing Column 393: Monroe County, Alabama!!Households!!Estimate
# Extracted Data - County: Monroe County, State: Alabama, Metric: 30,235
# Processing Column 401: Montgomery County, Alabama!!Households!!Estimate
# Extracted Data - County: Montgomery County, State: Alabama, Metric: 43,725
# Processing Column 409: Morgan County, Alabama!!Households!!Estimate
# Extracted Data - County: Morgan County, State: Alabama, Metric: 44,349
# Processing Column 417: Perry County, Alabama!!Households!!Estimate
# Extracted Data - County: Perry County, State: Alabama, Metric: 25,950
# Processing Column 425: Pickens County, Alabama!!Households!!Estimate
# Extracted Data - County: Pickens County, State: Alabama, Metric: 28,280
# Processing Column 433: Pike County, Alabama!!Households!!Estimate
# Extracted Data - County: Pike County, State: Alabama, Metric: 29,181
# Processing Column 441: Randolph County, Alabama!!Households!!Estimate
# Extracted Data - County: Randolph County, State: Alabama, Metric: 34,593
# Processing Column 449: Russell County, Alabama!!Households!!Estimate
# Extracted Data - County: Russell County, State: Alabama, Metric: 32,481
# Processing Column 457: St. Clair County, Alabama!!Households!!Estimate
# Extracted Data - County: St. Clair County, State: Alabama, Metric: 48,837
# Processing Column 465: Shelby County, Alabama!!Households!!Estimate
# Extracted Data - County: Shelby County, State: Alabama, Metric: 68,380
# Processing Column 473: Sumter County, Alabama!!Households!!Estimate
# Extracted Data - County: Sumter County, State: Alabama, Metric: 25,338
# Processing Column 481: Talladega County, Alabama!!Households!!Estimate
# Extracted Data - County: Talladega County, State: Alabama, Metric: 36,948
# Processing Column 489: Tallapoosa County, Alabama!!Households!!Estimate
# Extracted Data - County: Tallapoosa County, State: Alabama, Metric: 36,904
# Processing Column 497: Tuscaloosa County, Alabama!!Households!!Estimate
# Extracted Data - County: Tuscaloosa County, State: Alabama, Metric: 42,311
# Processing Column 505: Walker County, Alabama!!Households!!Estimate
# Extracted Data - County: Walker County, State: Alabama, Metric: 37,191
# Processing Column 513: Washington County, Alabama!!Households!!Estimate
# Extracted Data - County: Washington County, State: Alabama, Metric: 36,431
# Processing Column 521: Wilcox County, Alabama!!Households!!Estimate
# Extracted Data - County: Wilcox County, State: Alabama, Metric: 23,491
# Processing Column 529: Winston County, Alabama!!Households!!Estimate
# Extracted Data - County: Winston County, State: Alabama, Metric: 33,685
# Processing Column 537: Aleutians East Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Aleutians East Borough, State: Alaska, Metric: 54,375
# Processing Column 545: Aleutians West Census Area, Alaska!!Households!!Estimate
# Extracted Data - County: Aleutians West Census Area, State: Alaska, Metric: 72,917
# Processing Column 553: Anchorage Municipality, Alaska!!Households!!Estimate
# Extracted Data - County: Anchorage Municipality, State: Alaska, Metric: 73,004
# Processing Column 561: Bethel Census Area, Alaska!!Households!!Estimate
# Extracted Data - County: Bethel Census Area, State: Alaska, Metric: 52,214
# Processing Column 569: Bristol Bay Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Bristol Bay Borough, State: Alaska, Metric: 84,000
# Processing Column 577: Denali Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Denali Borough, State: Alaska, Metric: 72,500
# Processing Column 585: Dillingham Census Area, Alaska!!Households!!Estimate
# Extracted Data - County: Dillingham Census Area, State: Alaska, Metric: 60,800
# Processing Column 593: Fairbanks North Star Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Fairbanks North Star Borough, State: Alaska, Metric: 66,598
# Processing Column 601: Haines Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Haines Borough, State: Alaska, Metric: 47,981
# Processing Column 609: Hoonah-Angoon Census Area, Alaska!!Households!!Estimate
# Extracted Data - County: Hoonah-Angoon Census Area, State: Alaska, Metric: 43,750
# Processing Column 617: Juneau City and Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Juneau City and Borough, State: Alaska, Metric: 75,517
# Processing Column 625: Kenai Peninsula Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Kenai Peninsula Borough, State: Alaska, Metric: 57,454
# Processing Column 633: Ketchikan Gateway Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Ketchikan Gateway Borough, State: Alaska, Metric: 61,695
# Processing Column 641: Kodiak Island Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Kodiak Island Borough, State: Alaska, Metric: 60,776
# Processing Column 649: Lake and Peninsula Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Lake and Peninsula Borough, State: Alaska, Metric: 40,909
# Processing Column 657: Matanuska-Susitna Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Matanuska-Susitna Borough, State: Alaska, Metric: 67,703
# Processing Column 665: Nome Census Area, Alaska!!Households!!Estimate
# Extracted Data - County: Nome Census Area, State: Alaska, Metric: 53,899
# Processing Column 673: North Slope Borough, Alaska!!Households!!Estimate
# Extracted Data - County: North Slope Borough, State: Alaska, Metric: 68,517
# Processing Column 681: Northwest Arctic Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Northwest Arctic Borough, State: Alaska, Metric: 55,217
# Processing Column 689: Petersburg Census Area, Alaska!!Households!!Estimate
# Extracted Data - County: Petersburg Census Area, State: Alaska, Metric: 62,317
# Processing Column 697: Prince of Wales-Hyder Census Area, Alaska!!Households!!Estimate
# Extracted Data - County: Prince of Wales-Hyder Census Area, State: Alaska, Metric: 45,728
# Processing Column 705: Sitka City and Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Sitka City and Borough, State: Alaska, Metric: 62,024
# Processing Column 713: Skagway Municipality, Alaska!!Households!!Estimate
# Extracted Data - County: Skagway Municipality, State: Alaska, Metric: 73,500
# Processing Column 721: Southeast Fairbanks Census Area, Alaska!!Households!!Estimate
# Extracted Data - County: Southeast Fairbanks Census Area, State: Alaska, Metric: 59,596
# Processing Column 729: Valdez-Cordova Census Area, Alaska!!Households!!Estimate
# Extracted Data - County: Valdez-Cordova Census Area, State: Alaska, Metric: 60,383
# Processing Column 737: Wade Hampton Census Area, Alaska!!Households!!Estimate
# Extracted Data - County: Wade Hampton Census Area, State: Alaska, Metric: 37,955
# Processing Column 745: Wrangell City and Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Wrangell City and Borough, State: Alaska, Metric: 50,389
# Processing Column 753: Yakutat City and Borough, Alaska!!Households!!Estimate
# Extracted Data - County: Yakutat City and Borough, State: Alaska, Metric: 65,750
# Processing Column 761: Yukon-Koyukuk Census Area, Alaska!!Households!!Estimate
# Extracted Data - County: Yukon-Koyukuk Census Area, State: Alaska, Metric: 33,712
# Processing Column 769: Apache County, Arizona!!Households!!Estimate
# Extracted Data - County: Apache County, State: Arizona, Metric: 30,184
# Processing Column 777: Cochise County, Arizona!!Households!!Estimate
# Extracted Data - County: Cochise County, State: Arizona, Metric: 44,876
# Processing Column 785: Coconino County, Arizona!!Households!!Estimate
# Extracted Data - County: Coconino County, State: Arizona, Metric: 49,510
# Processing Column 793: Gila County, Arizona!!Households!!Estimate
# Extracted Data - County: Gila County, State: Arizona, Metric: 37,580
# Processing Column 801: Graham County, Arizona!!Households!!Estimate
# Extracted Data - County: Graham County, State: Arizona, Metric: 41,683
# Processing Column 809: Greenlee County, Arizona!!Households!!Estimate
# Extracted Data - County: Greenlee County, State: Arizona, Metric: 48,696
# Processing Column 817: La Paz County, Arizona!!Households!!Estimate
# Extracted Data - County: La Paz County, State: Arizona, Metric: 32,147
# Processing Column 825: Maricopa County, Arizona!!Households!!Estimate
# Extracted Data - County: Maricopa County, State: Arizona, Metric: 55,054
# Processing Column 833: Mohave County, Arizona!!Households!!Estimate
# Extracted Data - County: Mohave County, State: Arizona, Metric: 39,785
# Processing Column 841: Navajo County, Arizona!!Households!!Estimate
# Extracted Data - County: Navajo County, State: Arizona, Metric: 39,774
# Processing Column 849: Pima County, Arizona!!Households!!Estimate
# Extracted Data - County: Pima County, State: Arizona, Metric: 45,521
# Processing Column 857: Pinal County, Arizona!!Households!!Estimate
# Extracted Data - County: Pinal County, State: Arizona, Metric: 51,310
# Processing Column 865: Santa Cruz County, Arizona!!Households!!Estimate
# Extracted Data - County: Santa Cruz County, State: Arizona, Metric: 36,519
# Processing Column 873: Yavapai County, Arizona!!Households!!Estimate
# Extracted Data - County: Yavapai County, State: Arizona, Metric: 43,290
# Processing Column 881: Yuma County, Arizona!!Households!!Estimate
# Extracted Data - County: Yuma County, State: Arizona, Metric: 40,340
# Processing Column 889: Arkansas County, Arkansas!!Households!!Estimate
# Extracted Data - County: Arkansas County, State: Arkansas, Metric: 37,230
# Processing Column 897: Ashley County, Arkansas!!Households!!Estimate
# Extracted Data - County: Ashley County, State: Arkansas, Metric: 34,934
# Processing Column 905: Baxter County, Arkansas!!Households!!Estimate
# Extracted Data - County: Baxter County, State: Arkansas, Metric: 35,606
# Processing Column 913: Benton County, Arkansas!!Households!!Estimate
# Extracted Data - County: Benton County, State: Arkansas, Metric: 50,434
# Processing Column 921: Boone County, Arkansas!!Households!!Estimate
# Extracted Data - County: Boone County, State: Arkansas, Metric: 36,977
# Processing Column 929: Bradley County, Arkansas!!Households!!Estimate
# Extracted Data - County: Bradley County, State: Arkansas, Metric: 29,908
# Processing Column 937: Calhoun County, Arkansas!!Households!!Estimate
# Extracted Data - County: Calhoun County, State: Arkansas, Metric: 32,450
# Processing Column 945: Carroll County, Arkansas!!Households!!Estimate
# Extracted Data - County: Carroll County, State: Arkansas, Metric: 34,235
# Processing Column 953: Chicot County, Arkansas!!Households!!Estimate
# Extracted Data - County: Chicot County, State: Arkansas, Metric: 21,676
# Processing Column 961: Clark County, Arkansas!!Households!!Estimate
# Extracted Data - County: Clark County, State: Arkansas, Metric: 31,968
# Processing Column 969: Clay County, Arkansas!!Households!!Estimate
# Extracted Data - County: Clay County, State: Arkansas, Metric: 29,066
# Processing Column 977: Cleburne County, Arkansas!!Households!!Estimate
# Extracted Data - County: Cleburne County, State: Arkansas, Metric: 35,753
# Processing Column 985: Cleveland County, Arkansas!!Households!!Estimate
# Extracted Data - County: Cleveland County, State: Arkansas, Metric: 36,957
# Processing Column 993: Columbia County, Arkansas!!Households!!Estimate
# Extracted Data - County: Columbia County, State: Arkansas, Metric: 35,148
# Processing Column 1001: Conway County, Arkansas!!Households!!Estimate
# Extracted Data - County: Conway County, State: Arkansas, Metric: 32,700
# Processing Column 1009: Craighead County, Arkansas!!Households!!Estimate
# Extracted Data - County: Craighead County, State: Arkansas, Metric: 39,233
# Processing Column 1017: Crawford County, Arkansas!!Households!!Estimate
# Extracted Data - County: Crawford County, State: Arkansas, Metric: 40,197
# Processing Column 1025: Crittenden County, Arkansas!!Households!!Estimate
# Extracted Data - County: Crittenden County, State: Arkansas, Metric: 33,716
# Processing Column 1033: Cross County, Arkansas!!Households!!Estimate
# Extracted Data - County: Cross County, State: Arkansas, Metric: 37,021
# Processing Column 1041: Dallas County, Arkansas!!Households!!Estimate
# Extracted Data - County: Dallas County, State: Arkansas, Metric: 29,602
# Processing Column 1049: Desha County, Arkansas!!Households!!Estimate
# Extracted Data - County: Desha County, State: Arkansas, Metric: 29,051
# Processing Column 1057: Drew County, Arkansas!!Households!!Estimate
# Extracted Data - County: Drew County, State: Arkansas, Metric: 32,558
# Processing Column 1065: Faulkner County, Arkansas!!Households!!Estimate
# Extracted Data - County: Faulkner County, State: Arkansas, Metric: 45,287
# Processing Column 1073: Franklin County, Arkansas!!Households!!Estimate
# Extracted Data - County: Franklin County, State: Arkansas, Metric: 32,064
# Processing Column 1081: Fulton County, Arkansas!!Households!!Estimate
# Extracted Data - County: Fulton County, State: Arkansas, Metric: 30,598
# Processing Column 1089: Garland County, Arkansas!!Households!!Estimate
# Extracted Data - County: Garland County, State: Arkansas, Metric: 36,844
# Processing Column 1097: Grant County, Arkansas!!Households!!Estimate
# Extracted Data - County: Grant County, State: Arkansas, Metric: 51,589
# Processing Column 1105: Greene County, Arkansas!!Households!!Estimate
# Extracted Data - County: Greene County, State: Arkansas, Metric: 38,209
# Processing Column 1113: Hempstead County, Arkansas!!Households!!Estimate
# Extracted Data - County: Hempstead County, State: Arkansas, Metric: 35,708
# Processing Column 1121: Hot Spring County, Arkansas!!Households!!Estimate
# Extracted Data - County: Hot Spring County, State: Arkansas, Metric: 37,150
# Processing Column 1129: Howard County, Arkansas!!Households!!Estimate
# Extracted Data - County: Howard County, State: Arkansas, Metric: 34,554
# Processing Column 1137: Independence County, Arkansas!!Households!!Estimate
# Extracted Data - County: Independence County, State: Arkansas, Metric: 34,625
# Processing Column 1145: Izard County, Arkansas!!Households!!Estimate
# Extracted Data - County: Izard County, State: Arkansas, Metric: 31,673
# Processing Column 1153: Jackson County, Arkansas!!Households!!Estimate
# Extracted Data - County: Jackson County, State: Arkansas, Metric: 27,615
# Processing Column 1161: Jefferson County, Arkansas!!Households!!Estimate
# Extracted Data - County: Jefferson County, State: Arkansas, Metric: 35,998
# Processing Column 1169: Johnson County, Arkansas!!Households!!Estimate
# Extracted Data - County: Johnson County, State: Arkansas, Metric: 30,592
# Processing Column 1177: Lafayette County, Arkansas!!Households!!Estimate
# Extracted Data - County: Lafayette County, State: Arkansas, Metric: 27,515
# Processing Column 1185: Lawrence County, Arkansas!!Households!!Estimate
# Extracted Data - County: Lawrence County, State: Arkansas, Metric: 30,288
# Processing Column 1193: Lee County, Arkansas!!Households!!Estimate
# Extracted Data - County: Lee County, State: Arkansas, Metric: 30,494
# Processing Column 1201: Lincoln County, Arkansas!!Households!!Estimate
# Extracted Data - County: Lincoln County, State: Arkansas, Metric: 35,737
# Processing Column 1209: Little River County, Arkansas!!Households!!Estimate
# Extracted Data - County: Little River County, State: Arkansas, Metric: 33,416
# Processing Column 1217: Logan County, Arkansas!!Households!!Estimate
# Extracted Data - County: Logan County, State: Arkansas, Metric: 37,551
# Processing Column 1225: Lonoke County, Arkansas!!Households!!Estimate
# Extracted Data - County: Lonoke County, State: Arkansas, Metric: 50,757
# Processing Column 1233: Madison County, Arkansas!!Households!!Estimate
# Extracted Data - County: Madison County, State: Arkansas, Metric: 36,502
# Processing Column 1241: Marion County, Arkansas!!Households!!Estimate
# Extracted Data - County: Marion County, State: Arkansas, Metric: 34,109
# Processing Column 1249: Miller County, Arkansas!!Households!!Estimate
# Extracted Data - County: Miller County, State: Arkansas, Metric: 40,307
# Processing Column 1257: Mississippi County, Arkansas!!Households!!Estimate
# Extracted Data - County: Mississippi County, State: Arkansas, Metric: 33,407
# Processing Column 1265: Monroe County, Arkansas!!Households!!Estimate
# Extracted Data - County: Monroe County, State: Arkansas, Metric: 29,964
# Processing Column 1273: Montgomery County, Arkansas!!Households!!Estimate
# Extracted Data - County: Montgomery County, State: Arkansas, Metric: 35,705
# Processing Column 1281: Nevada County, Arkansas!!Households!!Estimate
# Extracted Data - County: Nevada County, State: Arkansas, Metric: 38,375
# Processing Column 1289: Newton County, Arkansas!!Households!!Estimate
# Extracted Data - County: Newton County, State: Arkansas, Metric: 27,441
# Processing Column 1297: Ouachita County, Arkansas!!Households!!Estimate
# Extracted Data - County: Ouachita County, State: Arkansas, Metric: 31,259
# Processing Column 1305: Perry County, Arkansas!!Households!!Estimate
# Extracted Data - County: Perry County, State: Arkansas, Metric: 43,635
# Processing Column 1313: Phillips County, Arkansas!!Households!!Estimate
# Extracted Data - County: Phillips County, State: Arkansas, Metric: 27,361
# Processing Column 1321: Pike County, Arkansas!!Households!!Estimate
# Extracted Data - County: Pike County, State: Arkansas, Metric: 32,806
# Processing Column 1329: Poinsett County, Arkansas!!Households!!Estimate
# Extracted Data - County: Poinsett County, State: Arkansas, Metric: 32,267
# Processing Column 1337: Polk County, Arkansas!!Households!!Estimate
# Extracted Data - County: Polk County, State: Arkansas, Metric: 32,525
# Processing Column 1345: Pope County, Arkansas!!Households!!Estimate
# Extracted Data - County: Pope County, State: Arkansas, Metric: 39,841
# Processing Column 1353: Prairie County, Arkansas!!Households!!Estimate
# Extracted Data - County: Prairie County, State: Arkansas, Metric: 35,346
# Processing Column 1361: Pulaski County, Arkansas!!Households!!Estimate
# Extracted Data - County: Pulaski County, State: Arkansas, Metric: 45,121
# Processing Column 1369: Randolph County, Arkansas!!Households!!Estimate
# Extracted Data - County: Randolph County, State: Arkansas, Metric: 30,222
# Processing Column 1377: St. Francis County, Arkansas!!Households!!Estimate
# Extracted Data - County: St. Francis County, State: Arkansas, Metric: 27,019
# Processing Column 1385: Saline County, Arkansas!!Households!!Estimate
# Extracted Data - County: Saline County, State: Arkansas, Metric: 51,502
# Processing Column 1393: Scott County, Arkansas!!Households!!Estimate
# Extracted Data - County: Scott County, State: Arkansas, Metric: 36,417
# Processing Column 1401: Searcy County, Arkansas!!Households!!Estimate
# Extracted Data - County: Searcy County, State: Arkansas, Metric: 28,811
# Processing Column 1409: Sebastian County, Arkansas!!Households!!Estimate
# Extracted Data - County: Sebastian County, State: Arkansas, Metric: 39,482
# Processing Column 1417: Sevier County, Arkansas!!Households!!Estimate
# Extracted Data - County: Sevier County, State: Arkansas, Metric: 34,383
# Processing Column 1425: Sharp County, Arkansas!!Households!!Estimate
# Extracted Data - County: Sharp County, State: Arkansas, Metric: 31,135
# Processing Column 1433: Stone County, Arkansas!!Households!!Estimate
# Extracted Data - County: Stone County, State: Arkansas, Metric: 30,380
# Processing Column 1441: Union County, Arkansas!!Households!!Estimate
# Extracted Data - County: Union County, State: Arkansas, Metric: 36,464
# Processing Column 1449: Van Buren County, Arkansas!!Households!!Estimate
# Extracted Data - County: Van Buren County, State: Arkansas, Metric: 31,960
# Processing Column 1457: Washington County, Arkansas!!Households!!Estimate
# Extracted Data - County: Washington County, State: Arkansas, Metric: 42,303
# Processing Column 1465: White County, Arkansas!!Households!!Estimate
# Extracted Data - County: White County, State: Arkansas, Metric: 39,178
# Processing Column 1473: Woodruff County, Arkansas!!Households!!Estimate
# Extracted Data - County: Woodruff County, State: Arkansas, Metric: 27,186
# Processing Column 1481: Yell County, Arkansas!!Households!!Estimate
# Extracted Data - County: Yell County, State: Arkansas, Metric: 36,606
# Processing Column 1489: Alameda County, California!!Households!!Estimate
# Extracted Data - County: Alameda County, State: California, Metric: 69,384
# Processing Column 1497: Alpine County, California!!Households!!Estimate
# Extracted Data - County: Alpine County, State: California, Metric: 63,478
# Processing Column 1505: Amador County, California!!Households!!Estimate
# Extracted Data - County: Amador County, State: California, Metric: 54,758
# Processing Column 1513: Butte County, California!!Households!!Estimate
# Extracted Data - County: Butte County, State: California, Metric: 43,170
# Processing Column 1521: Calaveras County, California!!Households!!Estimate
# Extracted Data - County: Calaveras County, State: California, Metric: 54,971
# Processing Column 1529: Colusa County, California!!Households!!Estimate
# Extracted Data - County: Colusa County, State: California, Metric: 48,016
# Processing Column 1537: Contra Costa County, California!!Households!!Estimate
# Extracted Data - County: Contra Costa County, State: California, Metric: 78,385
# Processing Column 1545: Del Norte County, California!!Households!!Estimate
# Extracted Data - County: Del Norte County, State: California, Metric: 36,118
# Processing Column 1553: El Dorado County, California!!Households!!Estimate
# Extracted Data - County: El Dorado County, State: California, Metric: 70,000
# Processing Column 1561: Fresno County, California!!Households!!Estimate
# Extracted Data - County: Fresno County, State: California, Metric: 46,430
# Processing Column 1569: Glenn County, California!!Households!!Estimate
# Extracted Data - County: Glenn County, State: California, Metric: 43,074
# Processing Column 1577: Humboldt County, California!!Households!!Estimate
# Extracted Data - County: Humboldt County, State: California, Metric: 40,089
# Processing Column 1585: Imperial County, California!!Households!!Estimate
# Extracted Data - County: Imperial County, State: California, Metric: 38,685
# Processing Column 1593: Inyo County, California!!Households!!Estimate
# Extracted Data - County: Inyo County, State: California, Metric: 44,808
# Processing Column 1601: Kern County, California!!Households!!Estimate
# Extracted Data - County: Kern County, State: California, Metric: 47,089
# Processing Column 1609: Kings County, California!!Households!!Estimate
# Extracted Data - County: Kings County, State: California, Metric: 48,684
# Processing Column 1617: Lake County, California!!Households!!Estimate
# Extracted Data - County: Lake County, State: California, Metric: 39,491
# Processing Column 1625: Lassen County, California!!Households!!Estimate
# Extracted Data - County: Lassen County, State: California, Metric: 50,317
# Processing Column 1633: Los Angeles County, California!!Households!!Estimate
# Extracted Data - County: Los Angeles County, State: California, Metric: 55,476
# Processing Column 1641: Madera County, California!!Households!!Estimate
# Extracted Data - County: Madera County, State: California, Metric: 46,039
# Processing Column 1649: Marin County, California!!Households!!Estimate
# Extracted Data - County: Marin County, State: California, Metric: 89,268
# Processing Column 1657: Mariposa County, California!!Households!!Estimate
# Extracted Data - County: Mariposa County, State: California, Metric: 49,098
# Processing Column 1665: Mendocino County, California!!Households!!Estimate
# Extracted Data - County: Mendocino County, State: California, Metric: 43,759
# Processing Column 1673: Merced County, California!!Households!!Estimate
# Extracted Data - County: Merced County, State: California, Metric: 43,844
# Processing Column 1681: Modoc County, California!!Households!!Estimate
# Extracted Data - County: Modoc County, State: California, Metric: 34,588
# Processing Column 1689: Mono County, California!!Households!!Estimate
# Extracted Data - County: Mono County, State: California, Metric: 55,087
# Processing Column 1697: Monterey County, California!!Households!!Estimate
# Extracted Data - County: Monterey County, State: California, Metric: 59,271
# Processing Column 1705: Napa County, California!!Households!!Estimate
# Extracted Data - County: Napa County, State: California, Metric: 67,389
# Processing Column 1713: Nevada County, California!!Households!!Estimate
# Extracted Data - County: Nevada County, State: California, Metric: 57,121
# Processing Column 1721: Orange County, California!!Households!!Estimate
# Extracted Data - County: Orange County, State: California, Metric: 74,344
# Processing Column 1729: Placer County, California!!Households!!Estimate
# Extracted Data - County: Placer County, State: California, Metric: 74,447
# Processing Column 1737: Plumas County, California!!Households!!Estimate
# Extracted Data - County: Plumas County, State: California, Metric: 44,000
# Processing Column 1745: Riverside County, California!!Households!!Estimate
# Extracted Data - County: Riverside County, State: California, Metric: 57,768
# Processing Column 1753: Sacramento County, California!!Households!!Estimate
# Extracted Data - County: Sacramento County, State: California, Metric: 56,439
# Processing Column 1761: San Benito County, California!!Households!!Estimate
# Extracted Data - County: San Benito County, State: California, Metric: 65,771
# Processing Column 1769: San Bernardino County, California!!Households!!Estimate
# Extracted Data - County: San Bernardino County, State: California, Metric: 55,845
# Processing Column 1777: San Diego County, California!!Households!!Estimate
# Extracted Data - County: San Diego County, State: California, Metric: 63,069
# Processing Column 1785: San Francisco County, California!!Households!!Estimate
# Extracted Data - County: San Francisco County, State: California, Metric: 71,304
# Processing Column 1793: San Joaquin County, California!!Households!!Estimate
# Extracted Data - County: San Joaquin County, State: California, Metric: 54,341
# Processing Column 1801: San Luis Obispo County, California!!Households!!Estimate
# Extracted Data - County: San Luis Obispo County, State: California, Metric: 57,365
# Processing Column 1809: San Mateo County, California!!Households!!Estimate
# Extracted Data - County: San Mateo County, State: California, Metric: 85,648
# Processing Column 1817: Santa Barbara County, California!!Households!!Estimate
# Extracted Data - County: Santa Barbara County, State: California, Metric: 60,078
# Processing Column 1825: Santa Clara County, California!!Households!!Estimate
# Extracted Data - County: Santa Clara County, State: California, Metric: 86,850
# Processing Column 1833: Santa Cruz County, California!!Households!!Estimate
# Extracted Data - County: Santa Cruz County, State: California, Metric: 65,253
# Processing Column 1841: Shasta County, California!!Households!!Estimate
# Extracted Data - County: Shasta County, State: California, Metric: 43,944
# Processing Column 1849: Sierra County, California!!Households!!Estimate
# Extracted Data - County: Sierra County, State: California, Metric: 52,950
# Processing Column 1857: Siskiyou County, California!!Households!!Estimate
# Extracted Data - County: Siskiyou County, State: California, Metric: 36,981
# Processing Column 1865: Solano County, California!!Households!!Estimate
# Extracted Data - County: Solano County, State: California, Metric: 68,409
# Processing Column 1873: Sonoma County, California!!Households!!Estimate
# Extracted Data - County: Sonoma County, State: California, Metric: 63,274
# Processing Column 1881: Stanislaus County, California!!Households!!Estimate
# Extracted Data - County: Stanislaus County, State: California, Metric: 51,094
# Processing Column 1889: Sutter County, California!!Households!!Estimate
# Extracted Data - County: Sutter County, State: California, Metric: 50,944
# Processing Column 1897: Tehama County, California!!Households!!Estimate
# Extracted Data - County: Tehama County, State: California, Metric: 38,137
# Processing Column 1905: Trinity County, California!!Households!!Estimate
# Extracted Data - County: Trinity County, State: California, Metric: 38,725
# Processing Column 1913: Tulare County, California!!Households!!Estimate
# Extracted Data - County: Tulare County, State: California, Metric: 43,851
# Processing Column 1921: Tuolumne County, California!!Households!!Estimate
# Extracted Data - County: Tuolumne County, State: California, Metric: 47,462
# Processing Column 1929: Ventura County, California!!Households!!Estimate
# Extracted Data - County: Ventura County, State: California, Metric: 75,348
# Processing Column 1937: Yolo County, California!!Households!!Estimate
# Extracted Data - County: Yolo County, State: California, Metric: 57,077
# Processing Column 1945: Yuba County, California!!Households!!Estimate
# Extracted Data - County: Yuba County, State: California, Metric: 46,807
# Processing Column 1953: Adams County, Colorado!!Households!!Estimate
# Extracted Data - County: Adams County, State: Colorado, Metric: 54,666
# Processing Column 1961: Alamosa County, Colorado!!Households!!Estimate
# Extracted Data - County: Alamosa County, State: Colorado, Metric: 35,935
# Processing Column 1969: Arapahoe County, Colorado!!Households!!Estimate
# Extracted Data - County: Arapahoe County, State: Colorado, Metric: 58,719
# Processing Column 1977: Archuleta County, Colorado!!Households!!Estimate
# Extracted Data - County: Archuleta County, State: Colorado, Metric: 56,068
# Processing Column 1985: Baca County, Colorado!!Households!!Estimate
# Extracted Data - County: Baca County, State: Colorado, Metric: 36,017
# Processing Column 1993: Bent County, Colorado!!Households!!Estimate
# Extracted Data - County: Bent County, State: Colorado, Metric: 36,412
# Processing Column 2001: Boulder County, Colorado!!Households!!Estimate
# Extracted Data - County: Boulder County, State: Colorado, Metric: 64,839
# Processing Column 2009: Broomfield County, Colorado!!Households!!Estimate
# Extracted Data - County: Broomfield County, State: Colorado, Metric: 75,590
# Processing Column 2017: Chaffee County, Colorado!!Households!!Estimate
# Extracted Data - County: Chaffee County, State: Colorado, Metric: 42,941
# Processing Column 2025: Cheyenne County, Colorado!!Households!!Estimate
# Extracted Data - County: Cheyenne County, State: Colorado, Metric: 47,125
# Processing Column 2033: Clear Creek County, Colorado!!Households!!Estimate
# Extracted Data - County: Clear Creek County, State: Colorado, Metric: 60,426
# Processing Column 2041: Conejos County, Colorado!!Households!!Estimate
# Extracted Data - County: Conejos County, State: Colorado, Metric: 33,627
# Processing Column 2049: Costilla County, Colorado!!Households!!Estimate
# Extracted Data - County: Costilla County, State: Colorado, Metric: 24,388
# Processing Column 2057: Crowley County, Colorado!!Households!!Estimate
# Extracted Data - County: Crowley County, State: Colorado, Metric: 38,189
# Processing Column 2065: Custer County, Colorado!!Households!!Estimate
# Extracted Data - County: Custer County, State: Colorado, Metric: 39,909
# Processing Column 2073: Delta County, Colorado!!Households!!Estimate
# Extracted Data - County: Delta County, State: Colorado, Metric: 40,451
# Processing Column 2081: Denver County, Colorado!!Households!!Estimate
# Extracted Data - County: Denver County, State: Colorado, Metric: 45,501
# Processing Column 2089: Dolores County, Colorado!!Households!!Estimate
# Extracted Data - County: Dolores County, State: Colorado, Metric: 43,058
# Processing Column 2097: Douglas County, Colorado!!Households!!Estimate
# Extracted Data - County: Douglas County, State: Colorado, Metric: 99,198
# Processing Column 2105: Eagle County, Colorado!!Households!!Estimate
# Extracted Data - County: Eagle County, State: Colorado, Metric: 71,337
# Processing Column 2113: Elbert County, Colorado!!Households!!Estimate
# Extracted Data - County: Elbert County, State: Colorado, Metric: 78,958
# Processing Column 2121: El Paso County, Colorado!!Households!!Estimate
# Extracted Data - County: El Paso County, State: Colorado, Metric: 56,268
# Processing Column 2129: Fremont County, Colorado!!Households!!Estimate
# Extracted Data - County: Fremont County, State: Colorado, Metric: 37,847
# Processing Column 2137: Garfield County, Colorado!!Households!!Estimate
# Extracted Data - County: Garfield County, State: Colorado, Metric: 64,902
# Processing Column 2145: Gilpin County, Colorado!!Households!!Estimate
# Extracted Data - County: Gilpin County, State: Colorado, Metric: 58,036
# Processing Column 2153: Grand County, Colorado!!Households!!Estimate
# Extracted Data - County: Grand County, State: Colorado, Metric: 60,433
# Processing Column 2161: Gunnison County, Colorado!!Households!!Estimate
# Extracted Data - County: Gunnison County, State: Colorado, Metric: 49,356
# Processing Column 2169: Hinsdale County, Colorado!!Households!!Estimate
# Extracted Data - County: Hinsdale County, State: Colorado, Metric: 74,659
# Processing Column 2177: Huerfano County, Colorado!!Households!!Estimate
# Extracted Data - County: Huerfano County, State: Colorado, Metric: 30,058
# Processing Column 2185: Jackson County, Colorado!!Households!!Estimate
# Extracted Data - County: Jackson County, State: Colorado, Metric: 37,222
# Processing Column 2193: Jefferson County, Colorado!!Households!!Estimate
# Extracted Data - County: Jefferson County, State: Colorado, Metric: 66,075
# Processing Column 2201: Kiowa County, Colorado!!Households!!Estimate
# Extracted Data - County: Kiowa County, State: Colorado, Metric: 40,089
# Processing Column 2209: Kit Carson County, Colorado!!Households!!Estimate
# Extracted Data - County: Kit Carson County, State: Colorado, Metric: 41,678
# Processing Column 2217: Lake County, Colorado!!Households!!Estimate
# Extracted Data - County: Lake County, State: Colorado, Metric: 41,103
# Processing Column 2225: La Plata County, Colorado!!Households!!Estimate
# Extracted Data - County: La Plata County, State: Colorado, Metric: 56,422
# Processing Column 2233: Larimer County, Colorado!!Households!!Estimate
# Extracted Data - County: Larimer County, State: Colorado, Metric: 56,447
# Processing Column 2241: Las Animas County, Colorado!!Households!!Estimate
# Extracted Data - County: Las Animas County, State: Colorado, Metric: 38,134
# Processing Column 2249: Lincoln County, Colorado!!Households!!Estimate
# Extracted Data - County: Lincoln County, State: Colorado, Metric: 41,616
# Processing Column 2257: Logan County, Colorado!!Households!!Estimate
# Extracted Data - County: Logan County, State: Colorado, Metric: 40,961
# Processing Column 2265: Mesa County, Colorado!!Households!!Estimate
# Extracted Data - County: Mesa County, State: Colorado, Metric: 52,067
# Processing Column 2273: Mineral County, Colorado!!Households!!Estimate
# Extracted Data - County: Mineral County, State: Colorado, Metric: 53,438
# Processing Column 2281: Moffat County, Colorado!!Households!!Estimate
# Extracted Data - County: Moffat County, State: Colorado, Metric: 53,587
# Processing Column 2289: Montezuma County, Colorado!!Households!!Estimate
# Extracted Data - County: Montezuma County, State: Colorado, Metric: 44,103
# Processing Column 2297: Montrose County, Colorado!!Households!!Estimate
# Extracted Data - County: Montrose County, State: Colorado, Metric: 46,590
# Processing Column 2305: Morgan County, Colorado!!Households!!Estimate
# Extracted Data - County: Morgan County, State: Colorado, Metric: 43,111
# Processing Column 2313: Otero County, Colorado!!Households!!Estimate
# Extracted Data - County: Otero County, State: Colorado, Metric: 34,142
# Processing Column 2321: Ouray County, Colorado!!Households!!Estimate
# Extracted Data - County: Ouray County, State: Colorado, Metric: 58,393
# Processing Column 2329: Park County, Colorado!!Households!!Estimate
# Extracted Data - County: Park County, State: Colorado, Metric: 64,098
# Processing Column 2337: Phillips County, Colorado!!Households!!Estimate
# Extracted Data - County: Phillips County, State: Colorado, Metric: 44,084
# Processing Column 2345: Pitkin County, Colorado!!Households!!Estimate
# Extracted Data - County: Pitkin County, State: Colorado, Metric: 64,502
# Processing Column 2353: Prowers County, Colorado!!Households!!Estimate
# Extracted Data - County: Prowers County, State: Colorado, Metric: 33,969
# Processing Column 2361: Pueblo County, Colorado!!Households!!Estimate
# Extracted Data - County: Pueblo County, State: Colorado, Metric: 40,699
# Processing Column 2369: Rio Blanco County, Colorado!!Households!!Estimate
# Extracted Data - County: Rio Blanco County, State: Colorado, Metric: 57,992
# Processing Column 2377: Rio Grande County, Colorado!!Households!!Estimate
# Extracted Data - County: Rio Grande County, State: Colorado, Metric: 39,871
# Processing Column 2385: Routt County, Colorado!!Households!!Estimate
# Extracted Data - County: Routt County, State: Colorado, Metric: 60,876
# Processing Column 2393: Saguache County, Colorado!!Households!!Estimate
# Extracted Data - County: Saguache County, State: Colorado, Metric: 30,430
# Processing Column 2401: San Juan County, Colorado!!Households!!Estimate
# Extracted Data - County: San Juan County, State: Colorado, Metric: 43,783
# Processing Column 2409: San Miguel County, Colorado!!Households!!Estimate
# Extracted Data - County: San Miguel County, State: Colorado, Metric: 66,399
# Processing Column 2417: Sedgwick County, Colorado!!Households!!Estimate
# Extracted Data - County: Sedgwick County, State: Colorado, Metric: 37,625
# ...
# Processing Column 24953: Wood County, Wisconsin!!Households!!Estimate
# Extracted Data - County: Wood County, State: Wisconsin, Metric: 47,204
# Processing Column 24961: Albany County, Wyoming!!Households!!Estimate
# Extracted Data - County: Albany County, State: Wyoming, Metric: 42,890
# Processing Column 24969: Big Horn County, Wyoming!!Households!!Estimate
# Extracted Data - County: Big Horn County, State: Wyoming, Metric: 48,270
# Processing Column 24977: Campbell County, Wyoming!!Households!!Estimate
# Extracted Data - County: Campbell County, State: Wyoming, Metric: 76,576
# Processing Column 24985: Carbon County, Wyoming!!Households!!Estimate
# Extracted Data - County: Carbon County, State: Wyoming, Metric: 56,565
# Processing Column 24993: Converse County, Wyoming!!Households!!Estimate
# Extracted Data - County: Converse County, State: Wyoming, Metric: 54,599
# Processing Column 25001: Crook County, Wyoming!!Households!!Estimate
# Extracted Data - County: Crook County, State: Wyoming, Metric: 49,890
# Processing Column 25009: Fremont County, Wyoming!!Households!!Estimate
# Extracted Data - County: Fremont County, State: Wyoming, Metric: 46,397
# Processing Column 25017: Goshen County, Wyoming!!Households!!Estimate
# Extracted Data - County: Goshen County, State: Wyoming, Metric: 42,590
# Processing Column 25025: Hot Springs County, Wyoming!!Households!!Estimate
# Extracted Data - County: Hot Springs County, State: Wyoming, Metric: 42,469
# Processing Column 25033: Johnson County, Wyoming!!Households!!Estimate
# Extracted Data - County: Johnson County, State: Wyoming, Metric: 45,638
# Processing Column 25041: Laramie County, Wyoming!!Households!!Estimate
# Extracted Data - County: Laramie County, State: Wyoming, Metric: 52,824
# Processing Column 25049: Lincoln County, Wyoming!!Households!!Estimate
# Extracted Data - County: Lincoln County, State: Wyoming, Metric: 57,794
# Processing Column 25057: Natrona County, Wyoming!!Households!!Estimate
# Extracted Data - County: Natrona County, State: Wyoming, Metric: 50,936
# Processing Column 25065: Niobrara County, Wyoming!!Households!!Estimate
# Extracted Data - County: Niobrara County, State: Wyoming, Metric: 45,813
# Processing Column 25073: Park County, Wyoming!!Households!!Estimate
# Extracted Data - County: Park County, State: Wyoming, Metric: 46,637
# Processing Column 25081: Platte County, Wyoming!!Households!!Estimate
# Extracted Data - County: Platte County, State: Wyoming, Metric: 42,947
# Processing Column 25089: Sheridan County, Wyoming!!Households!!Estimate
# Extracted Data - County: Sheridan County, State: Wyoming, Metric: 48,141
# Processing Column 25097: Sublette County, Wyoming!!Households!!Estimate
# Extracted Data - County: Sublette County, State: Wyoming, Metric: 70,147
# Processing Column 25105: Sweetwater County, Wyoming!!Households!!Estimate
# Extracted Data - County: Sweetwater County, State: Wyoming, Metric: 69,828
# Processing Column 25113: Teton County, Wyoming!!Households!!Estimate
# Extracted Data - County: Teton County, State: Wyoming, Metric: 70,271
# Processing Column 25121: Uinta County, Wyoming!!Households!!Estimate
# Extracted Data - County: Uinta County, State: Wyoming, Metric: 58,346
# Processing Column 25129: Washakie County, Wyoming!!Households!!Estimate
# Extracted Data - County: Washakie County, State: Wyoming, Metric: 48,379
# Processing Column 25137: Weston County, Wyoming!!Households!!Estimate
# Extracted Data - County: Weston County, State: Wyoming, Metric: 53,853
# Processing Column 25145: Adjuntas Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Adjuntas Municipio, State: Puerto Rico, Metric: 11,983
# Processing Column 25153: Aguada Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Aguada Municipio, State: Puerto Rico, Metric: 14,103
# Processing Column 25161: Aguadilla Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Aguadilla Municipio, State: Puerto Rico, Metric: 13,956
# Processing Column 25169: Aguas Buenas Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Aguas Buenas Municipio, State: Puerto Rico, Metric: 14,751
# Processing Column 25177: Aibonito Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Aibonito Municipio, State: Puerto Rico, Metric: 15,487
# Processing Column 25185: Añasco Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Añasco Municipio, State: Puerto Rico, Metric: 15,244
# Processing Column 25193: Arecibo Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Arecibo Municipio, State: Puerto Rico, Metric: 16,564
# Processing Column 25201: Arroyo Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Arroyo Municipio, State: Puerto Rico, Metric: 14,815
# Processing Column 25209: Barceloneta Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Barceloneta Municipio, State: Puerto Rico, Metric: 16,124
# Processing Column 25217: Barranquitas Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Barranquitas Municipio, State: Puerto Rico, Metric: 14,751
# Processing Column 25225: Bayamón Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Bayamón Municipio, State: Puerto Rico, Metric: 25,294
# Processing Column 25233: Cabo Rojo Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Cabo Rojo Municipio, State: Puerto Rico, Metric: 15,809
# Processing Column 25241: Caguas Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Caguas Municipio, State: Puerto Rico, Metric: 22,951
# Processing Column 25249: Camuy Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Camuy Municipio, State: Puerto Rico, Metric: 14,985
# Processing Column 25257: Canóvanas Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Canóvanas Municipio, State: Puerto Rico, Metric: 21,934
# Processing Column 25265: Carolina Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Carolina Municipio, State: Puerto Rico, Metric: 28,262
# Processing Column 25273: Cataño Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Cataño Municipio, State: Puerto Rico, Metric: 18,144
# Processing Column 25281: Cayey Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Cayey Municipio, State: Puerto Rico, Metric: 19,040
# Processing Column 25289: Ceiba Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Ceiba Municipio, State: Puerto Rico, Metric: 18,461
# Processing Column 25297: Ciales Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Ciales Municipio, State: Puerto Rico, Metric: 13,564
# Processing Column 25305: Cidra Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Cidra Municipio, State: Puerto Rico, Metric: 21,293
# Processing Column 25313: Coamo Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Coamo Municipio, State: Puerto Rico, Metric: 15,028
# Processing Column 25321: Comerío Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Comerío Municipio, State: Puerto Rico, Metric: 12,927
# Processing Column 25329: Corozal Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Corozal Municipio, State: Puerto Rico, Metric: 14,077
# Processing Column 25337: Culebra Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Culebra Municipio, State: Puerto Rico, Metric: 19,868
# Processing Column 25345: Dorado Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Dorado Municipio, State: Puerto Rico, Metric: 25,473
# Processing Column 25353: Fajardo Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Fajardo Municipio, State: Puerto Rico, Metric: 19,803
# Processing Column 25361: Florida Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Florida Municipio, State: Puerto Rico, Metric: 16,246
# Processing Column 25369: Guánica Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Guánica Municipio, State: Puerto Rico, Metric: 11,870
# Processing Column 25377: Guayama Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Guayama Municipio, State: Puerto Rico, Metric: 17,214
# Processing Column 25385: Guayanilla Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Guayanilla Municipio, State: Puerto Rico, Metric: 14,243
# Processing Column 25393: Guaynabo Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Guaynabo Municipio, State: Puerto Rico, Metric: 33,279
# Processing Column 25401: Gurabo Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Gurabo Municipio, State: Puerto Rico, Metric: 27,416
# Processing Column 25409: Hatillo Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Hatillo Municipio, State: Puerto Rico, Metric: 16,246
# Processing Column 25417: Hormigueros Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Hormigueros Municipio, State: Puerto Rico, Metric: 19,834
# Processing Column 25425: Humacao Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Humacao Municipio, State: Puerto Rico, Metric: 18,354
# Processing Column 25433: Isabela Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Isabela Municipio, State: Puerto Rico, Metric: 13,028
# Processing Column 25441: Jayuya Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Jayuya Municipio, State: Puerto Rico, Metric: 15,556
# Processing Column 25449: Juana Díaz Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Juana Díaz Municipio, State: Puerto Rico, Metric: 16,496
# Processing Column 25457: Juncos Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Juncos Municipio, State: Puerto Rico, Metric: 17,694
# Processing Column 25465: Lajas Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Lajas Municipio, State: Puerto Rico, Metric: 14,500
# Processing Column 25473: Lares Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Lares Municipio, State: Puerto Rico, Metric: 12,199
# Processing Column 25481: Las Marías Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Las Marías Municipio, State: Puerto Rico, Metric: 13,847
# Processing Column 25489: Las Piedras Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Las Piedras Municipio, State: Puerto Rico, Metric: 17,680
# Processing Column 25497: Loíza Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Loíza Municipio, State: Puerto Rico, Metric: 19,460
# Processing Column 25505: Luquillo Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Luquillo Municipio, State: Puerto Rico, Metric: 19,672
# Processing Column 25513: Manatí Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Manatí Municipio, State: Puerto Rico, Metric: 16,564
# Processing Column 25521: Maricao Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Maricao Municipio, State: Puerto Rico, Metric: 10,932
# Processing Column 25529: Maunabo Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Maunabo Municipio, State: Puerto Rico, Metric: 15,225
# Processing Column 25537: Mayagüez Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Mayagüez Municipio, State: Puerto Rico, Metric: 14,059
# Processing Column 25545: Moca Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Moca Municipio, State: Puerto Rico, Metric: 12,841
# Processing Column 25553: Morovis Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Morovis Municipio, State: Puerto Rico, Metric: 13,646
# Processing Column 25561: Naguabo Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Naguabo Municipio, State: Puerto Rico, Metric: 15,250
# Processing Column 25569: Naranjito Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Naranjito Municipio, State: Puerto Rico, Metric: 14,275
# Processing Column 25577: Orocovis Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Orocovis Municipio, State: Puerto Rico, Metric: 13,713
# Processing Column 25585: Patillas Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Patillas Municipio, State: Puerto Rico, Metric: 14,860
# Processing Column 25593: Peñuelas Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Peñuelas Municipio, State: Puerto Rico, Metric: 14,872
# Processing Column 25601: Ponce Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Ponce Municipio, State: Puerto Rico, Metric: 16,902
# Processing Column 25609: Quebradillas Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Quebradillas Municipio, State: Puerto Rico, Metric: 11,943
# Processing Column 25617: Rincón Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Rincón Municipio, State: Puerto Rico, Metric: 16,067
# Processing Column 25625: Río Grande Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Río Grande Municipio, State: Puerto Rico, Metric: 20,850
# Processing Column 25633: Sabana Grande Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Sabana Grande Municipio, State: Puerto Rico, Metric: 15,497
# Processing Column 25641: Salinas Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Salinas Municipio, State: Puerto Rico, Metric: 13,118
# Processing Column 25649: San Germán Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: San Germán Municipio, State: Puerto Rico, Metric: 15,016
# Processing Column 25657: San Juan Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: San Juan Municipio, State: Puerto Rico, Metric: 23,478
# Processing Column 25665: San Lorenzo Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: San Lorenzo Municipio, State: Puerto Rico, Metric: 17,477
# Processing Column 25673: San Sebastián Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: San Sebastián Municipio, State: Puerto Rico, Metric: 12,115
# Processing Column 25681: Santa Isabel Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Santa Isabel Municipio, State: Puerto Rico, Metric: 17,605
# Processing Column 25689: Toa Alta Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Toa Alta Municipio, State: Puerto Rico, Metric: 25,133
# Processing Column 25697: Toa Baja Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Toa Baja Municipio, State: Puerto Rico, Metric: 23,297
# Processing Column 25705: Trujillo Alto Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Trujillo Alto Municipio, State: Puerto Rico, Metric: 30,825
# Processing Column 25713: Utuado Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Utuado Municipio, State: Puerto Rico, Metric: 13,509
# Processing Column 25721: Vega Alta Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Vega Alta Municipio, State: Puerto Rico, Metric: 16,608
# Processing Column 25729: Vega Baja Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Vega Baja Municipio, State: Puerto Rico, Metric: 16,530
# Processing Column 25737: Vieques Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Vieques Municipio, State: Puerto Rico, Metric: 16,220
# Processing Column 25745: Villalba Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Villalba Municipio, State: Puerto Rico, Metric: 15,455
# Processing Column 25753: Yabucoa Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Yabucoa Municipio, State: Puerto Rico, Metric: 16,894
# Processing Column 25761: Yauco Municipio, Puerto Rico!!Households!!Estimate
# Extracted Data - County: Yauco Municipio, State: Puerto Rico, Metric: 14,314
#   State          County  Metric
# 0    AL  Autauga County  53,255
# 1    AL  Baldwin County  50,147
# 2    AL  Barbour County  33,219
# 3    AL     Bibb County  41,770
# 4    AL   Blount County  45,549

# %%
# Ensure that the 'Metric' column is converted to string, remove commas, and convert back to int
income_df['Metric'] = income_df['Metric'].astype(str).str.replace(',', '').astype(int)

# Assign levels based on percentile bins
income_df['Income Level'] = pd.qcut(
    income_df['Metric'],
    q=[0, 0.2, 0.4, 0.6, 0.8, 1],   # Define the percentiles
    labels=[5, 4, 3, 2, 1]          # Labels for each percentile group
).astype(int)

income_df.head()
# Out:
#   State          County  Metric  Income Level
# 0    AL  Autauga County   53255             1
# 1    AL  Baldwin County   50147             2
# 2    AL  Barbour County   33219             5
# 3    AL     Bibb County   41770             3
# 4    AL   Blount County   45549             2

# %%
income_df
# Out:
#      State             County  Metric  Income Level
# 0       AL     Autauga County   53255             1
# 1       AL     Baldwin County   50147             2
# 2       AL     Barbour County   33219             5
# 3       AL        Bibb County   41770             3
# 4       AL      Blount County   45549             2
# ...    ...                ...     ...           ...
# 3138    WY  Sweetwater County   69828             1
# 3139    WY       Teton County   70271             1
# 3140    WY       Uinta County   58346             1
# 3141    WY    Washakie County   48379             2
# 3142    WY      Weston County   53853             1
#
# [3143 rows x 4 columns]

# %%
df = pd.read_excel("/workspaces/TSA-Data_Science-24-25/raw data/DECENNIALDHC2020.P9-2025-01-10T101403.xlsx", sheet_name="Data")

df.iloc[:11, :2]
# Out:
#                                                Label Autauga County, Alabama
# 0                                             Total:                  58,805
# 1                                 Hispanic or Latino                   2,117
# 2                            Not Hispanic or Latino:                  56,688
# 3                            Population of one race:                  54,198
# 4                                        White alone                  41,582
# 5                    Black or African American alone                  11,352
# 6            American Indian and Alaska Native alone                     184
# 7                                        Asian alone                     873
# 8   Native Hawaiian and Other Pacific Islander alone                      22
# 9                              Some Other Race alone                     185
# 10                  Population of two or more races:                   2,490

# %%
states = []
counties = []
top_races = []

for column in df.columns[1:]:
    # Extract county and state from the column name (split by comma)
    county, state = column.split(", ")
    state_abbr = state_abbrev.get(state, state)
    
    # Extract the population numbers (all rows except 'Label' row)
    population_data = df[column].values

    # Convert each value in the population_data to a string, remove commas, and convert back to int
    population_data = [int(str(val).replace(',', '')) for val in population_data]

    # Get population values for each race category
    total, races = population_data[0], [population_data[4], population_data[5], 
    population_data[1], population_data[7], population_data[8], 
    population_data[6], population_data[9] + population_data[10]]

    # Calculate percentages and labels for each race group
    race_percentages = [round(races[0] / total * 100), round(races[1] / total * 100), round(races[2] / total * 100), 
                        round(races[3] / total * 100), round(races[4] / total * 100), round(races[5] / total * 100), 
                        round(races[6] / total * 100)]
    race_labels = ['W', 'B', 'H', 'A', 'P', 'N', 'O']

    # Create a list of (percentage, race_label) tuples
    race_data = [(race_percentages[i], race_labels[i]) for i in range(len(race_percentages))]

    # Sort the list of race data by percentage in descending order
    sorted_race_data = sorted(race_data, key=lambda x: x[0], reverse=True)
    
    # Build the race string by iterating over the sorted list and adding races above the 30% threshold
    race_string = ""
    for percentage, race_label in sorted_race_data:
        if percentage >= 30:
            race_string += race_label
    if race_string == "":
        race_string = "E"
    
    # Append to the list
    top_races.append(race_string)
    states.append(state_abbr)
    counties.append(county)

# Create the new dataframe with the state, county, and the top races
race_df = pd.DataFrame({
    'State': states,
    'County': counties,
    'Top Races': top_races
})

# Remove Puerto Rico rows
race_df = race_df[race_df['State'] != 'Puerto Rico']

race_df.head()
# Out:
#   State          County Top Races
# 0    AL  Autauga County         W
# 1    AL  Baldwin County         W
# 2    AL  Barbour County        BW
# 3    AL     Bibb County         W
# 4    AL   Blount County         W

# %%
race_df
# Out:
#      State             County Top Races
# 0       AL     Autauga County         W
# 1       AL     Baldwin County         W
# 2       AL     Barbour County        BW
# 3       AL        Bibb County         W
# 4       AL      Blount County         W
# ...    ...                ...       ...
# 3138    WY  Sweetwater County         W
# 3139    WY       Teton County         W
# 3140    WY       Uinta County         W
# 3141    WY    Washakie County         W
# 3142    WY      Weston County         W
#
# [3143 rows x 3 columns]

# %%
lowtier_df = pd.read_csv("/workspaces/TSA-Data_Science-24-25/raw data/City_zhvi_uc_sfrcondo_tier_0.0_0.33_sm_sa_month.csv")
midtier_df = pd.read_csv("/workspaces/TSA-Data_Science-24-25/raw data/City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month (1).csv")
hightier_df = pd.read_csv("/workspaces/TSA-Data_Science-24-25/raw data/City_zhvi_uc_sfrcondo_tier_0.67_1.0_sm_sa_month.csv")

print("lowtier_df:\n", lowtier_df.head())
print("midtier_df:\n", midtier_df.head())
print("hightier_df:\n", hightier_df.head())
# Out:
# lowtier_df:
#    State                      Metropolitan Area              County  \
# 0    NY  New York-Newark-Jersey City, NY-NJ-PA       Queens County
# 1    CA     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County
# 2    TX   Houston-The Woodlands-Sugar Land, TX       Harris County
# 3    IL     Chicago-Naperville-Elgin, IL-IN-WI         Cook County
# 4    TX          San Antonio-New Braunfels, TX        Bexar County
#
#           City        Jan-06        Feb-06        Mar-06        Apr-06  \
# 0     New York  271773.15940  275366.63600  277944.33220  280244.01150
# 1  Los Angeles  324969.88010  328290.38720  331652.70670  334440.63130
# 2      Houston   70025.82616   69974.22515   69940.54027   69983.11000
# 3      Chicago  126133.15390  127280.17840  128340.06990  129284.15440
# 4  San Antonio   66039.45972   66238.56018   66431.74135   66676.58333
#
#         May-06        Jun-06  ...        Mar-10        Apr-10        May-10  \
# 0  282808.5711  285603.96950  ...  256626.77060  256472.02560  256661.98540
# 1  337917.3319  341013.50950  ...  222012.06280  222873.79480  224760.94690
# 2   70288.0059   70595.44407  ...   69253.13054   69457.33374   69640.56414
# 3  130075.7469  130544.30160  ...  100526.43090  100774.89410  100552.26020
# 4   66998.4943   67434.80978  ...   70058.93858   70087.12667   70180.89909
#
#          Jun-10        Jul-10        Aug-10        Sep-10        Oct-10  \
# 0  257584.20110  258597.98990  259098.47570  259522.52180  259618.56670
# 1  224776.24180  224022.67350  221967.86880  219950.34790  218004.93070
# 2   69652.51410   69318.02221   68701.42700   68080.40714   67574.98745
# 3  100950.45660   99789.53189   98769.39927   97318.09424   96220.96467
# 4   70152.45689   70136.71046   70180.54285   70200.73787   70051.89876
#
#          Nov-10        Dec-10
# 0  259241.72850  258067.33610
# 1  216221.38460  215511.60390
# 2   67266.54364   66992.96362
# 3   94810.15518   93333.11823
# 4   69657.88165   69246.93307
#
# [5 rows x 64 columns]
# midtier_df:
#    State                      Metropolitan Area              County  \
# 0    NY  New York-Newark-Jersey City, NY-NJ-PA       Queens County
# 1    CA     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County
# 3  5.715847e+05  5.729954e+05  ...  4.461005e+05  4.470648e+05  4.458909e+05
# 4  2.054054e+05  2.066871e+05  ...  2.117142e+05  2.121381e+05  2.125702e+05
#
#          Jun-10        Jul-10        Aug-10        Sep-10        Oct-10  \
# 0  1.099103e+06  1.104840e+06  1.109851e+06  1.114661e+06  1.117419e+06
# 1  7.853399e+05  7.823003e+05  7.746588e+05  7.656140e+05  7.566198e+05
# 2  2.644407e+05  2.633443e+05  2.610592e+05  2.589025e+05  2.571945e+05
# 3  4.475403e+05  4.431160e+05  4.395150e+05  4.336614e+05  4.290512e+05
# 4  2.126809e+05  2.126695e+05  2.127269e+05  2.126661e+05  2.121040e+05
#
#          Nov-10        Dec-10
# 0  1.117309e+06  1.114193e+06
# 1  7.483628e+05  7.452383e+05
# 2  2.563344e+05  2.556453e+05
# 3  4.232324e+05  4.176005e+05
# 4  2.108790e+05  2.096505e+05
#
# [5 rows x 64 columns]

# %%
# Merge income_df and race_df on State and County
combined_income_race = pd.merge(income_df, race_df, on=["State", "County"], how="inner")
combined_income_race = combined_income_race.rename(columns={"Top Races": "Racial Groups"})
combined_income_race.drop('Metric', axis=1, inplace=True)

combined_income_race.head()
# Out:
#   State          County  Income Level Racial Groups
# 0    AL  Autauga County             1             W
# 1    AL  Baldwin County             2             W
# 2    AL  Barbour County             5            BW
# 3    AL     Bibb County             3             W
# 4    AL   Blount County             2             W

# %%
# Renaming columns for lowtier, midtier, and hightier datasets
def rename(df, type):
    rename_key = {col: f"{col} ZHVI | {type}" for col in df.columns if col not in ['State', 'Metropolitan Area', 'County', 'City']}
    return df.rename(columns=rename_key)

lowtier_df = rename(lowtier_df, "Low-Tier")
midtier_df = rename(midtier_df, "Mid-Tier")
hightier_df = rename(hightier_df, "High-Tier")

# %%
# Merge lowtier_df, midtier_df, and hightier_df on State, County, and City
low_mid_df = pd.merge(lowtier_df, midtier_df, on=["State", "Metropolitan Area", "County", "City"], how="inner")
low_mid_high_df = pd.merge(low_mid_df, hightier_df, on=["State", "Metropolitan Area", "County", "City"], how="inner")
low_mid_high_df = low_mid_high_df.dropna()
print(low_mid_high_df.columns.to_list())
low_mid_high_df
# Out:
# ['State', 'Metropolitan Area', 'County', 'City', 'Jan-06 ZHVI | Low-Tier', 'Feb-06 ZHVI | Low-Tier', 'Mar-06 ZHVI | Low-Tier', 'Apr-06 ZHVI | Low-Tier', 'May-06 ZHVI | Low-Tier', 'Jun-06 ZHVI | Low-Tier', 'Jul-06 ZHVI | Low-Tier', 'Aug-06 ZHVI | Low-Tier', 'Sep-06 ZHVI | Low-Tier', 'Oct-06 ZHVI | Low-Tier', 'Nov-06 ZHVI | Low-Tier', 'Dec-06 ZHVI | Low-Tier', 'Jan-07 ZHVI | Low-Tier', 'Feb-07 ZHVI | Low-Tier', 'Mar-07 ZHVI | Low-Tier', 'Apr-07 ZHVI | Low-Tier', 'May-07 ZHVI | Low-Tier', 'Jun-07 ZHVI | Low-Tier', 'Jul-07 ZHVI | Low-Tier', 'Aug-07
# 3                 4.395150e+05             4.336614e+05
# 4                 2.127269e+05             2.126661e+05
# ...                        ...                      ...
# 19766             1.188066e+05             1.183497e+05
# 19768             1.806280e+05             1.767468e+05
# 19780             1.625353e+05             1.626768e+05
# 19781             4.649443e+05             4.583435e+05
# 19785             1.868386e+05             1.865663e+05
#
#        Oct-10 ZHVI | High-Tier  Nov-10 ZHVI | High-Tier  \
# 0                 1.117419e+06             1.117309e+06
# 1                 7.566198e+05             7.483628e+05
# 2                 2.571945e+05             2.563344e+05
# 3                 4.290512e+05             4.232324e+05
# 4                 2.121040e+05             2.108790e+05
# ...                        ...                      ...
# 19766             1.170413e+05             1.151491e+05
# 19768             1.738648e+05             1.694534e+05
# 19780             1.623991e+05             1.618883e+05
# 19781             4.494842e+05             4.415563e+05
# 19785             1.863641e+05             1.860786e+05
#
#        Dec-10 ZHVI | High-Tier
# 0                 1.114193e+06
# 1                 7.452383e+05
# 2                 2.556453e+05
# 3                 4.176005e+05
# 4                 2.096505e+05
# ...                        ...
# 19766             1.127336e+05
# 19768             1.656952e+05
# 19780             1.615857e+05
# 19781             4.368349e+05
# 19785             1.851662e+05
#
# [8674 rows x 184 columns]

# %%
# Merge everything together
combined_df = pd.merge(low_mid_high_df, combined_income_race, on=["State", "County"], how='left')

print(combined_df.columns.to_list())
combined_df
# Out:
# ['State', 'Metropolitan Area', 'County', 'City', 'Jan-06 ZHVI | Low-Tier', 'Feb-06 ZHVI | Low-Tier', 'Mar-06 ZHVI | Low-Tier', 'Apr-06 ZHVI | Low-Tier', 'May-06 ZHVI | Low-Tier', 'Jun-06 ZHVI | Low-Tier', 'Jul-06 ZHVI | Low-Tier', 'Aug-06 ZHVI | Low-Tier', 'Sep-06 ZHVI | Low-Tier', 'Oct-06 ZHVI | Low-Tier', 'Nov-06 ZHVI | Low-Tier', 'Dec-06 ZHVI | Low-Tier', 'Jan-07 ZHVI | Low-Tier', 'Feb-07 ZHVI | Low-Tier', 'Mar-07 ZHVI | Low-Tier', 'Apr-07 ZHVI | Low-Tier', 'May-07 ZHVI | Low-Tier', 'Jun-07 ZHVI | Low-Tier', 'Jul-07 ZHVI | Low-Tier', 'Aug-07 ZHVI | Low-Tier', 'Sep-07 ZHVI | Low-Tier', 'Oct-07 ZHVI | Low-Tier', 'Nov-07 ZHVI | Low-Tier', 'Dec-07 ZHVI | Low-Tier', 'Jan-08 ZHVI | Low-Tier', 'Feb-08 ZHVI | Low-Tier', 'Mar-08 ZHVI | Low-Tier', 'Apr-08 ZHVI | Low-Tier', 'May-08 ZHVI | Low-Tier', 'Jun-08 ZHVI | Low-Tier', 'Jul-08 ZHVI | Low-Tier', 'Aug-08 ZHVI | Low-Tier', 'Sep-08 ZHVI | Low-Tier', 'Oct-08 ZHVI | Low-Tier', 'Nov-08 ZHVI | Low-Tier', 'Dec-08 ZHVI | Low-Tier', 'Jan-09 ZHVI | Low-Tier', 'Feb-09 ZHVI | Low-Tier', 'Mar-09 ZHVI | Low-Tier', 'Apr-09 ZHVI | Low
mid-Tier', 'Apr-10 ZHVI | Mid-Tier', 'May-10 ZHVI | Mid-Tier', 'Jun-10 ZHVI | Mid-Tier', 'Jul-10 ZHVI | Mid-Tier', 'Aug-10 ZHVI | Mid-Tier', 'Sep-10 ZHVI | Mid-Tier', 'Oct-10 ZHVI | Mid-Tier', 'Nov-10 ZHVI | Mid-Tier', 'Dec-10 ZHVI | Mid-Tier', 'Jan-06 ZHVI | High-Tier', 'Feb-06 ZHVI | High-Tier', 'Mar-06 ZHVI | High-Tier', 'Apr-06 ZHVI | High-Tier', 'May-06 ZHVI | High-Tier', 'Jun-06 ZHVI | High-Tier', 'Jul-06 ZHVI | High-Tier', 'Aug-06 ZHVI | High-Tier', 'Sep-06 ZHVI | High-Tier', 'Oct-06 ZHVI | High-Tier', 'Nov-06 ZHVI | High-Tier', 'Dec-06 ZHVI | High-Tier', 'Jan-07 ZHVI | High-Tier', 'Feb-07 ZHVI | High-Tier', 'Mar-07 ZHVI | High-Tier', 'Apr-07 ZHVI | High-Tier', 'May-07 ZHVI | High-Tier', 'Jun-07 ZHVI | High-Tier', 'Jul-07 ZHVI | High-Tier', 'Aug-07 ZHVI | High-Tier', 'Sep-07 ZHVI | High-Tier', 'Oct-07 ZHVI | High-Tier', 'Nov-07 ZHVI | High-Tier', 'Dec-07 ZHVI | High-Tier', 'Jan-08 ZHVI | High-Tier', 'Feb-08 ZHVI | High-Tier', 'Mar-08 ZHVI | High-Tier', 'Apr-08 ZHVI | High-Tier', 'May-08 ZHVI | High-Tier', 'Jun-08 ZHVI | High-Tier', 'Jul-08 ZHVI | High-T ...
#      State                      Metropolitan Area              County  \
# 0       NY  New York-Newark-Jersey City, NY-NJ-PA       Queens County
# 1       CA     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County
# 2       TX   Houston-The Woodlands-Sugar Land, TX       Harris County
# 3       IL     Chicago-Naperville-Elgin, IL-IN-WI         Cook County
# 4       TX          San Antonio-New Braunfels, TX        Bexar County
# ...    ...                                    ...                 ...
# 8669    MN                       Grand Rapids, MN       Itasca County
# 8670    WA             Spokane-Spokane Valley, WA      Spokane County
# 8671    WV                        Wheeling, WV-OH         Ohio County
# 8672    NV       Las Vegas-Henderson-Paradise, NV        Clark County
# 8673    OH                             Toledo, OH         Wood County
#
#                   City  Jan-06 ZHVI | Low-Tier  Feb-06 ZHVI | Low-Tier  \
# 0             New York            271773.15940            275366.63600
# 1          Los Angeles            324969.88010            328290.38720
# 2              Houston             70025.82616             69974.22515
# 3              Chicago            126133.15390            127280.17840
# 4          San Antonio             66039.45972             66238.56018
# ...                ...                     ...                     ...
# 8669             Bovey             48123.86595             48307.28283
# 8670         Fairfield             55232.04160             55875.95362
# 8671         Clearview             81604.33624             81673.79567
# 8672  Mount Charleston            228238.15170            229949.93900
# 8673           Haskins             67316.20545             67596.48490
#
#       Mar-06 ZHVI | Low-Tier  Apr-06 ZHVI | Low-Tier  May-06 ZHVI | Low-Tier  \
# 0               277944.33220            280244.01150            282808.57110
# 1               331652.70670            334440.63130            337917.33190
